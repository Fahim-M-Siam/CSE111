# %%
# Task1
class Student:
    ID = 0
    def __init__(self, n, d, a, g):
        Student.ID += 1
        self.id = Student.ID
        self.name = n
        self.dept = d
        self.age = a
        self.grade = g

    def get_details(self):
        print(
            f"ID: {self.id}\nName: {self.name}\nDepartment: {self.dept}\nAge: {self.age}\nCGPA: {self.grade}")

    @classmethod
    def from_String(cls, st):
        a = st.split('-')
        return cls(a[0], a[1], a[2], a[3])


s1 = Student("Samin", "CSE", 21, 3.91)
s1.get_details()
print("-----------------------")
s2 = Student("Fahim", "ECE", 21, 3.85)
s2.get_details()
print("-----------------------")
s3 = Student("Tahura", "EEE", 22, 3.01)
s3.get_details()
print("-----------------------")
s4 = Student.from_String("Sumaiya-BBA-23-3.96")
s4.get_details()
# Out:
# ID: 1
# Name: Samin
# Department: CSE
# Age: 21
# CGPA: 3.91
# -----------------------
# ID: 2
# Name: Fahim
# Department: ECE
# Age: 21
# CGPA: 3.85
# -----------------------
# ID: 3
# Name: Tahura
# Department: EEE
# Age: 22
# CGPA: 3.01
# -----------------------
# ID: 4
# Name: Sumaiya
# Department: BBA
# Age: 23
# CGPA: 3.96

# %%
# Task 2
class Assassin:
    assassinCount = 0

    def __init__(self, n, r):
        Assassin.assassinCount += 1
        self.Assassin_num = Assassin.assassinCount
        self.name = n
        self.rate = r

    def printDetails(self):
        print(
            f"Name: {self.name}\nSuccess rate: {self.rate}\nTotal number of Assassin: {self.Assassin_num}")

    @classmethod
    def failureRate(cls, n, f):
        return cls(n, 100 - f)

    @classmethod
    def failurePercentage(cls, n, f):
        return cls(n, 100-int(f[:-1]+'%'))


john_wick = Assassin('John Wick', 100)
john_wick.printDetails()
print('================================')
nagisa = Assassin.failureRate("Nagisa", 20)
nagisa.printDetails()
print('================================')
akabane = Assassin.failurePercentage("Akabane", "10%")
akabane.printDetails()
# Out:
# Name: John Wick
# Success rate: 100
# Total number of Assassin: 1
# ...
# Name: Nagisa
# Success rate: 80
# Total number of Assassin: 2
# ...
# Name: Akabane
# Success rate: 90
# Total number of Assassin: 3

# %%
# Task 3
class Passenger:
    count = 0

    def __init__(self, n):
        Passenger.count += 1
        self.passenger_count = Passenger.count
        self.name = n

    def set_bag_weight(self, n):
        if n <= 20:
            self.bus_fare = 450
        elif 20 >= n >= 50:
            self.bus_fare = 500
        else:
            self.bus_fare = 550

    def printDetail(self):
        print(f"Name: {self.name}\nBus Fare: {self.bus_fare} Taka")


print("Total Passenger:", Passenger.count)
p1 = Passenger("Jack")
p1.set_bag_weight(90)
p2 = Passenger("Carol")
p2.set_bag_weight(10)
p3 = Passenger("Mike")
p3.set_bag_weight(25)
print("=========================")
p1.printDetail()
print("=========================")
p2.printDetail()
print("=========================")
p3.printDetail()
print("=========================")
print("Total Passenger:", Passenger.count)
# Out:
# Total Passenger: 0
# ...
# Name: Jack
# Bus Fare: 550 Taka
# ...
# Name: Carol
# Bus Fare: 450 Taka
# ...
# Name: Mike
# Bus Fare: 550 Taka
# ...
# Total Passenger: 3

# %%
# task 4
class Travel:
    count = 0

    def __init__(self, s, d):
        Travel.count += 1
        self.Travel_count = Travel.count
        self.source = s
        self.destination = d
        self.ft = format(1, '.2f')

    def display_travel_info(self):
        return (f"Source: {self.source}\nDestinaion: {self.destination}\nFlight Time: {self.ft}")

    def set_time(self, t):
        self.ft = format(t, '.2f')

    def set_destination(self, d):
        self.destination = d

    def set_source(self, s):
        self.source = s


print("No. of Traveller =", Travel.count)
print("=======================")
t1 = Travel("Dhaka", "India")
print(t1.display_travel_info())
print("=======================")
t2 = Travel("Kuala Lampur", "Dhaka")
t2.set_time(23)
print(t2.display_travel_info())
print("=======================")
t3 = Travel("Dhaka", "New_Zealand")
t3.set_time(15)
t3.set_destination("Germany")
print(t3.display_travel_info())
print("=======================")
t4 = Travel("Dhaka", "India")
t4.set_time(9)
t4.set_source("Malaysia")
t4.set_destination("Canada")
print(t4.display_travel_info())
print("=======================")
print("No. of Traveller =", Travel.count)
# Out:
# No. of Traveller = 0
# ...
# Source: Dhaka
# Destinaion: India
# Flight Time: 1.00
# ...
# Source: Kuala Lampur
# Destinaion: Dhaka
# Flight Time: 23.00
# ...
# Source: Dhaka
# Destinaion: Germany
# Flight Time: 15.00
# ...
# Source: Malaysia
# Destinaion: Canada
# Flight Time: 9.00
# ...
# No. of Traveller = 4

# %%
# task 5
class Employee:
    def __init__(self, n, e):
        self.name = n
        self.workingPeriod = e

    @classmethod
    def employeeByJoiningYear(cls, n, y):
        workingPeriod = cls(n, (2022 - y))
        return (workingPeriod)

    @staticmethod
    def experienceCheck(y, g):
        gender = ''
        if g == "male":
            gender = "He"
        elif g == "female":
            gender = "She"

        if y > 3:
            return f"{gender} is experienced"
        else:
            return f"{gender} is not experienced"


employee1 = Employee('Dororo', 3)
employee2 = Employee.employeeByJoiningYear('Harry', 2016)
print(employee1.workingPeriod)
print(employee2.workingPeriod)
print(employee1.name)
print(employee2.name)
print(Employee.experienceCheck(2, "male"))
print(Employee.experienceCheck(3, "female"))
# Out:
# 3
# 6
# Dororo
# Harry
# He is not experienced
# She is not experienced

# %%
# task 6
class Laptop:
    laptopCount = 0

    def __init__(self, n, c):
        self.name = n
        self.count = c
        Laptop.laptopCount += self.count

    @staticmethod
    def advantage():
        print("Laptops are portable")

    @classmethod
    def resetCount(cls):
        cls.laptopCount = 0


lenovo = Laptop("Lenovo", 5)
dell = Laptop("Dell", 7)
print(lenovo.name, lenovo.count)
print(dell.name, dell.count)
print("Total number of Laptops", Laptop.laptopCount)
Laptop.advantage()
Laptop.resetCount()
print("Total number of Laptops", Laptop.laptopCount)
# Out:
# Lenovo 5
# Dell 7
# Total number of Laptops 12
# Laptops are portable
# Total number of Laptops 0

# %%
# Task 7
class Cat:
    Number_of_cats = 0

    def __init__(self, c, a):
        Cat.Number_of_cats += 1
        self.clr = c
        self.action = a

    def changeColor(self, c):
        self.clr = c

    def printCat(self):
        print(f"{self.clr} cat is {self.action}")

    @classmethod
    def no_parameter(cls):
        return cls("white", "sitting")

    @classmethod
    def first_parameter(cls, c):
        return cls(c, "sitting")

    @classmethod
    def second_parameter(cls, a):
        return cls("grey", a)


print("Total number of cats:", Cat.Number_of_cats)
c1 = Cat.no_parameter()
c2 = Cat.first_parameter("Black")
c3 = Cat("Brown", "jumping")
c4 = Cat("Red", "purring")
c5 = Cat.second_parameter("playing")
print("=======================")
c1.printCat()
c2.printCat()
c3.printCat()
c4.printCat()
c5.printCat()
c1.changeColor("Blue")
c3.changeColor("Purple")
c1.printCat()
c3.printCat()
print("=======================")
print("Total number of cats:", Cat.Number_of_cats)
# Out:
# Total number of cats: 0
# ...
# white cat is sitting
# Black cat is sitting
# Brown cat is jumping
# Red cat is purring
# grey cat is playing
# Blue cat is sitting
# Purple cat is jumping
# ...
# Total number of cats: 5

# %%
# Task 8
class Cylinder:
    radius = 5
    height = 18

    def __init__(self, r, h):
        self.radius = r
        self.height = h
        print(f"Default radius= {Cylinder.radius} and height={Cylinder.height}.")
        Cylinder.radius = r
        Cylinder.height = h
        print(f"Updated: radius = {Cylinder.radius} and height = {Cylinder.height}.")

    @classmethod
    def swap(cls, r, h):
        return cls(h,r)

    @classmethod
    def changeFormat(cls, st):
        a = st.split('-')
        obj = cls(float(a[0]), float(a[1]))
        return obj

    @staticmethod
    def area(r, h):
        area = (2*3.1416*(r**2)) + (2*3.1416*r*h)
        print(f"Area: {area}")

    @staticmethod
    def volume(r, h):
        volume = (3.1526*(r**2)*h)
        print(f"Volume: {volume}")


c1 = Cylinder(0, 0)
Cylinder.area(c1.radius, c1.height)
Cylinder.volume(c1.radius, c1.height)
print("===============================")
c2 = Cylinder.swap(8, 3)
c2.area(c2.radius, c2.height)
c2.volume(c2.radius, c2.height)
print("===============================")
c3 = Cylinder.changeFormat("7-13")
c3.area(c3.radius, c3.height)
c3.volume(c3.radius, c3.height)
print("===============================")
Cylinder(0.3, 5.56).area(Cylinder.radius, Cylinder.height)
print("===============================")
Cylinder(3, 5).volume(Cylinder.radius, Cylinder.height)
# Out:
# Default radius= 5 and height=18.
# Updated: radius = 0 and height = 0.
# Area: 0.0
# Volume: 0.0
# ...
# Default radius= 0 and height=0.
# Updated: radius = 3 and height = 8.
# Area: 207.3456
# Volume: 226.9872
# ...
# Default radius= 3 and height=8.
# Updated: radius = 7.0 and height = 13.0.
# Area: 879.648
# Volume: 2008.2062000000003
# ...
# Default radius= 7.0 and height=13.0.
# Updated: radius = 0.3 and height = 5.56.
# Area: 11.045865599999999
# ...
# Default radius= 0.3 and height=5.56.
# Updated: radius = 3 and height = 5.
# Volume: 141.867

# %%
#Task 9
class Student:
    total_students = 0
    bracu_students = 0
    other_students = 0
    def __init__(self,n,d,institution = "BRAC University"):
        self.name = n
        self.dept = d
        self.institution = institution
        if self.institution=="BRAC University":
            Student.bracu_students += 1
        else:
            Student.other_students += 1
        Student.total_students += 1

    def individualDetail(self):
        print(f"Name: {self.name}\nDepartment: {self.dept}\nInstitution: {self.institution}")

    @classmethod
    def createStudent(cls,n,d,i="BRAC University"):
        info = cls(n,d,i)
        return info
    
    @classmethod
    def printDetails(cls):
        print(f"Total student(s): {Student.total_students}\nBRAC University Student(s): {Student.bracu_students}\nOther Institution Student(s): {Student.other_students}")


Student.printDetails()
print('#########################')
mikasa = Student('Mikasa Ackerman', "CSE")
mikasa.individualDetail()
print('------------------------------------------')
Student.printDetails()
print('========================')
harry = Student.createStudent('Harry Potter', "Defence Against Dark Arts", "Hogwarts School")
harry.individualDetail()
print('-------------------------------------------')
Student.printDetails()
print('=========================')
levi = Student.createStudent("Levi Ackerman", "CSE")
levi.individualDetail()
print('--------------------------------------------')
Student.printDetails()
# Out:
# Total student(s): 0
# BRAC University Student(s): 0
# Other Institution Student(s): 0
# #########################
# Name: Mikasa Ackerman
# Department: CSE
# Institution: BRAC University
# ------------------------------------------
# Total student(s): 1
# BRAC University Student(s): 1
# Other Institution Student(s): 0
# ...
# Name: Harry Potter
# Department: Defence Against Dark Arts
# Institution: Hogwarts School
# -------------------------------------------
# Total student(s): 2
# BRAC University Student(s): 1
# Other Institution Student(s): 1
# ...
# Name: Levi Ackerman
# Department: CSE
# Institution: BRAC University
# --------------------------------------------
# Total student(s): 3
# BRAC University Student(s): 2
# Other Institution Student(s): 1

# %%
#Task 10
class SultansDine:
    Total_Number_0f_branch = 0
    Total_Sell = 0 
    branch_li = []
    def __init__(self,p):
        self.place = p
        SultansDine.Total_Number_0f_branch += 1
        SultansDine.branch_li.append(self)
    
    def sellQuantity(self,a):
        self.amount = a
        if self.amount < 10:
            self.amount = a*300
        elif self.amount < 20:
            self.amount = a*350
        else:
            self.amount = a*400
        self.branch_sell = self.amount
        SultansDine.Total_Sell += self.branch_sell
    
    def branchInformation(self):
        print(f"Branch Name: {self.place}\nBranch Sell: {self.branch_sell} Taka")
        

    @classmethod
    def details(cls):
        print(f"Total Number of branch(s): {len(SultansDine.branch_li)}\nTotal Sell: {SultansDine.Total_Sell} Taka")
        for i in cls.branch_li:
            print(f"Branch Name: {i.place}, Branch Sell: {i.branch_sell} Taka")
            sell_per_branch = (i.branch_sell/SultansDine.Total_Sell)*100
            print(f"Branch consists of total sell's: {round(sell_per_branch,2)}%")

SultansDine.details()
print('########################')
dhanmodi = SultansDine('Dhanmondi')
dhanmodi.sellQuantity(25)
dhanmodi.branchInformation()
print('-----------------------------------------')
SultansDine.details()
print('========================')
baily_road = SultansDine('Baily Road')
baily_road.sellQuantity(15)
baily_road.branchInformation()
print('-----------------------------------------')
SultansDine.details()
print('========================')
gulshan = SultansDine('Gulshan')
gulshan.sellQuantity(9)
gulshan.branchInformation()
print('-----------------------------------------')
SultansDine.details()
# Out:
# Total Number of branch(s): 0
# Total Sell: 0 Taka
# ########################
# Branch Name: Dhanmondi
# Branch Sell: 10000 Taka
# -----------------------------------------
# Total Number of branch(s): 1
# Total Sell: 10000 Taka
# Branch Name: Dhanmondi, Branch Sell: 10000 Taka
# Branch consists of total sell's: 100.0%
# ...
# Branch Name: Baily Road
# Branch Sell: 5250 Taka
# -----------------------------------------
# Total Number of branch(s): 2
# Total Sell: 15250 Taka
# Branch Name: Dhanmondi, Branch Sell: 10000 Taka
# Branch consists of total sell's: 65.57%
# Branch Name: Baily Road, Branch Sell: 5250 Taka
# Branch consists of total sell's: 34.43%
# ...
# Branch Name: Gulshan
# Branch Sell: 2700 Taka
# -----------------------------------------
